# %% [markdown]
# **Climate Change Machine Learning Using Microsoft**

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
import seaborn as sns; sns.set()

# %%
yearsBase, meanBase = np.loadtxt('1880-2023graph.csv', delimiter=',', usecols=(0, 1), unpack=True)
years, mean = np.loadtxt('1880-2023graph.csv', delimiter=',', usecols=(0, 1), unpack=True)

# %%
plt.scatter(yearsBase, meanBase)
plt.title('scatter plot of mean temp difference vs year')
plt.xlabel('years', fontsize=12)
plt.ylabel('mean temp difference', fontsize=12)
plt.show()

# %% [markdown]
# # Perform liner regression

# %%
# Creates a linear regression from the data points
m,b = np.polyfit(yearsBase, meanBase, 1)

# This is a simple y = mx + b line function
def f(x):
    return m*x + b

# This generates the same scatter plot as before, but adds a line plot using the function above
plt.scatter(yearsBase, meanBase)
plt.plot(yearsBase, f(yearsBase), 'red')
plt.title('scatter plot of mean temp difference vs year')
plt.xlabel('years', fontsize=12)
plt.ylabel('mean temp difference', fontsize=12)
plt.show()

# Prints text to the screen showing the computed values of m and b
print(' y = {0} * x + {1}'.format(m, b))
plt.show()
# Out:
#  y = 0.007964993257134467 * x + -15.939954702206101

# %% [markdown]
# # Performing linear regression using scikit-learn

# %%
# Pick the Linear Regression model and instantiate it
model = LinearRegression(fit_intercept=True)

# Fit/build the model
model.fit(yearsBase[:, np.newaxis], meanBase)
mean_predicted = model.predict(yearsBase[:, np.newaxis])

# Generate a plot like the one in the previous exercise
plt.scatter(yearsBase, meanBase)
plt.plot(yearsBase, mean_predicted, 'red')
plt.title('scatter plot of mean temp difference vs year')
plt.xlabel('years', fontsize=12)
plt.ylabel('mean temp difference', fontsize=12)
plt.show()

print(' y = {0} * x + {1}'.format(model.coef_[0], model.intercept_))
# Out:
#  y = 0.00796499325713444 * x + -15.939954702206057

# %% [markdown]
# # liner regression using seaborn

# %%
plt.scatter(years, mean)
plt.title('scatter plot of mean temp difference vs year')
plt.xlabel('years', fontsize=12)
plt.ylabel('mean temp difference', fontsize=12)
sns.regplot(yearsBase, meanBase)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\visual code\learning ml using vscode azure microsoft\climate change.ipynb Cell 10 line 5
#       <a href='vscode-notebook-cell:/d%3A/visual%20code/learning%20ml%20using%20vscode%20azure%20microsoft/climate%20change.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> plt.xlabel('years', fontsize=12)
#       <a href='vscode-notebook-cell:/d%3A/visual%20code/learning%20ml%20using%20vscode%20azure%20microsoft/climate%20change.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> plt.ylabel('mean temp difference', fontsize=12)
# ----> <a href='vscode-notebook-cell:/d%3A/visual%20code/learning%20ml%20using%20vscode%20azure%20microsoft/climate%20change.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a> sns.regplot(yearsBase, meanBase)
# ...
